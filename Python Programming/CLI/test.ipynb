# %%
Dict = {}

# %%
Dict.valu

# %%
def add_value(name, amount):
    Dict.update({name: amount})

# %%
def visual_cost(Dict):
    for key, value in Dict.items():
        print(f"{key}: {value}")
        print("*" * 50)

# %%
def sum_cost(Dict):
    total = 0
    for value in Dict.Values():
        total += value
        return total

# %%
boolean = True

while True:

    input_user = input("Enter you requirements: \n1- add value\n2-Visual_cost\n3-sum_cost\n4-Exit")

    if input == 4:
        print("GOODBYE!, Have a good Time")

    elif input_user == 1:
        good_name =
